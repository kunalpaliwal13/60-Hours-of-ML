# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
credit_data= pd.read_csv('/content/creditcard.csv')

# %%
credit_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_data.isnull().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6         True
# V7         True
# V8         True
# V9         True
# V10        True
# V11        True
# V12        True
# V13        True
# V14        True
# V15        True
# V16        True
# V17        True
# V18        True
# V19        True
# V20        True
# V21        True
# V22        True
# V23        True
# V24        True
# V25        True
# V26        True
# V27        True
# V28        True
# Amount     True
# Class      True
# dtype: bool

# %%
credit_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
credit_data.dropna(axis=0, inplace = True)

# %%
credit_data.isnull().any()
# Out:
# Time      False
# V1        False
# V2        False
# V3        False
# V4        False
# V5        False
# V6        False
# V7        False
# V8        False
# V9        False
# V10       False
# V11       False
# V12       False
# V13       False
# V14       False
# V15       False
# V16       False
# V17       False
# V18       False
# V19       False
# V20       False
# V21       False
# V22       False
# V23       False
# V24       False
# V25       False
# V26       False
# V27       False
# V28       False
# Amount    False
# Class     False
# dtype: bool

# %%
credit_data['Class'].value_counts()
#highly imbalanced
# Out:
# 0.0    45503
# 1.0      142
# Name: Class, dtype: int64

# %%
legit = credit_data[credit_data.Class==0]
fraud = credit_data[credit_data.Class==1]

# %%
print(legit.shape, fraud.shape)
# Out:
# (45503, 31) (142, 31)

# %% [markdown]
# **UnderSampling**

# %%
legit_sample = legit.sample(n=142)
#we take 142 data sample from legit , this is called undersampling

# %%
legit_sample.shape
# Out:
# (142, 31)

# %%
new_dataset = pd.concat([legit_sample,fraud], axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 35283  38048  1.219018 -0.629932 -0.121244  0.324611 -0.356218  0.362286
# 34204  37561 -1.533673  1.346587  1.585515  1.234174 -0.890852 -0.296674
# 37551  39006 -1.305768  0.213042 -0.243905 -1.147542 -3.448923  2.557722
# 45262  42271  0.348420 -0.940239 -0.099712  1.196659 -0.168015  0.386496
# 427      310 -1.236351 -0.687029  2.093407  0.601217  0.782303 -1.167113
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 35283 -0.347785  0.066467 -0.773874  ... -0.478992 -0.935384 -0.225893
# 34204 -0.104838  0.450313  0.583759  ...  0.000562  0.336182 -0.042764
# 37551  6.045010 -1.338655 -0.937061  ... -0.289344  0.223658 -0.222892
# 45262  0.599095  0.085997 -0.453245  ... -0.124814 -1.256783 -0.075805
# 427   -0.675395  0.232563  0.500531  ...  0.378832  0.841499  0.150103
#
#             V24       V25       V26       V27       V28   Amount  Class
# ...

# %%
new_dataset.shape
# Out:
# (284, 31)

# %%
new_dataset['Class'].value_counts()
# Out:
# 0.0    142
# 1.0    142
# Name: Class, dtype: int64
